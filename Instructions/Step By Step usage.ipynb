# %% [markdown]
# ## How to Demo
# ### FBC Databricks usage
#
# - Review the left Pane:
# Workspace, Catalog, Jobs, Compute, Marketplace
# SQL Management
# Data Engineering view
# AI/ML
#
# - Connect to a Github Repo
# https://github.com/jlagares/barcainnovationhub
#
# - Create a Notebook and Commit
# - Review the Catalog: System, User, Demo, and Connect to it in a notebook.
# ```
# df = spark.sql("""
# SELECT *
# FROM samples.bakehouse.media_customer_reviews
# LIMIT 5
# """)
# display(df)
# ```

# %%
df = spark.table("samples.bakehouse.media_customer_reviews").limit(5)
display(df)

# %% [markdown]
# ## Jobs
# - Create a job, show the capabilities of it.
# - Create a pipeline, explain Fan IN/OUT
# - Run it, see the logs

# %% [markdown]
# ##SQL
#
# - Overview of the SQL Editor and Queries, Show the query Editor and Plan on an execution
# - Dashboards and Queries, how to Create BI
# - Genie Concept, Free text to LLM
# - Alerts on tables
# - Query History
# - SQL Warehouse

# %% [markdown]
# # Runs
# Explain concept
#
# # AI/ML
# go into notebook for that...

# %% [markdown]
# #
